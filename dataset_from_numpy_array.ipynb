# %%
'''

Utilising from_tensor_slices

'''

# Converting Numpy arrays to Dataset
# When fitting use train_dataset and not X,y format

import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

# 
model = tf.keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(32,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
])

model.compile(optimizer='adam',
              loss='mse',
              metrics=['mae'])

# generate some big input datasets, bigger than 2GB
data = np.random.random((1024*1024*8, 32))
labels = np.random.random((1024*1024*8, 1))
val_data = np.random.random((100, 32))
val_labels = np.random.random((100, 1))

# Create Dataset from Numpy Arrays
train_dataset = tf.data.Dataset.from_tensor_slices((data, labels))
train_dataset = train_dataset.batch(32).repeat()
val_dataset = tf.data.Dataset.from_tensor_slices((val_data, val_labels))
val_dataset = val_dataset.batch(32).repeat()

# Train Model 
history = model.fit(train_dataset, 
          epochs=5, 
          steps_per_epoch=25,
          validation_data=val_dataset, 
          validation_steps=3,
          verbose=1)
# Out:
# Epoch 1/5
# 25/25 [==============================] - 1s 15ms/step - loss: 0.2760 - mae: 0.4167 - val_loss: 0.0874 - val_mae: 0.2551
# Epoch 2/5
# 25/25 [==============================] - 0s 14ms/step - loss: 0.1035 - mae: 0.2725 - val_loss: 0.0822 - val_mae: 0.2497
# Epoch 3/5
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0946 - mae: 0.2621 - val_loss: 0.0793 - val_mae: 0.2475
# Epoch 4/5
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0901 - mae: 0.2553 - val_loss: 0.0768 - val_mae: 0.2442
# Epoch 5/5
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0900 - mae: 0.2582 - val_loss: 0.0775 - val_mae: 0.2460
